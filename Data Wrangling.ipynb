# %%
import csv

# %%
# my_reader = csv.DictReader(open('data/eu_revolving_loans.csv', 'rb'))

# %%
abc = open('data/py3_requirements.txt', 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-daec87d6ba17> in <module>()
# ----> 1 abc = open('data/py3_requirements.txt', 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/py3_requirements.txt'

# %%
for x in abc:
    print(x)
# Out:
# backports-abc==0.4
#
# backports.shutil-get-terminal-size==1.0.0
#
# backports.ssl-match-hostname==3.5.0.1
#
# bokeh==0.11.1
#
# certifi==2016.2.28
#
# cffi==1.6.0
#
# cryptography==1.3.2
#
# cycler==0.10.0
#
# decorator==4.0.9
#
# entrypoints==0.2.1
#
# enum34==1.1.6
#
# et-xmlfile==1.0.1
#
# futures==3.0.5
#
# idna==2.1
#
# ipaddress==1.0.16
#
# ipykernel==4.3.1
#
# ipython==4.2.0
#
# ipython-genutils==0.1.0
#
# ipywidgets==5.1.3
#
# jdcal==1.2
#
# Jinja2==2.8
#
# jsonschema==2.5.1
#
# jupyter==1.0.0
#
# jupyter-client==4.2.2
#
# jupyter-console==4.1.1
#
# jupyter-core==4.1.0
#
# lxml==3.6.0
#
# MarkupSafe==0.23
#
# matplotlib==1.5.1
#
# mistune==0.7.2
#
# nbconvert==4.2.0
#
# nbformat==4.0.1
#
# ndg-httpsclient==0.4.0
#
# notebook==4.2.0
#
# numpy==1.11.0
#
# oauthlib==1.1.1
#
# openpyxl==2.3.5
#
# pandas==0.18.1
#
# pandas-datareader==0.2.1
#
# pathlib2==2.1.0
#
# pdfminer.six==20160614
#
# pdftables.six==0.0.5
#
# pexpect==4.0.1
#
# pickleshare==0.7.2
#
# ptyprocess==0.5.1
#
# ...
